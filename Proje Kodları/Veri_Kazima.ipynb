# %% [markdown]
# # Veri Kazıma Projesi

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup

# Kullanıcı ajanını değiştirme
options = Options()
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36")

# Chrome WebDriver Service objesi oluşturma
service = Service(ChromeDriverManager().install())

# WebDriver'ı başlatma
driver = webdriver.Chrome(service=service, options=options)

# Veri depolamak için bir liste
data = []

# Text temizleme fonksiyonları
def clean_room_text(text):
    if text:
        # "2 +\n 1" formatını "2+1" formatına çevirme
        return text.replace('\n', '').replace(' ', '').strip()
    return 'N/A'

def clean_age_text(text):
    if text:
        # "14\n at Age" formatını sadece "14" olarak temizleme
        return text.split('\n')[0].strip()
    return 'N/A'

# Sayfa boyunca gezme ve veri çekme
for page in range(1, 3):
    url = f'https://www.hepsiemlak.com/en/istanbul-satilik?sortDirection=ASC&sortField=PRICE&p31=1000000&p32=20000000&p33={page}'
    driver.get(url)
    
    # Sayfanın yüklenmesi için bekleme süresi
    time.sleep(10)
    
    # Sayfa kaynağını alma
    html = driver.page_source
    
    # BeautifulSoup ile sayfa kaynağını parse etme
    soup = BeautifulSoup(html, 'html.parser')
    
    # İlanları çekme - card-bottom-cage class'ına sahip div'leri bul
    listings = soup.find_all('div', class_='card-bottom-cage')
    
    # Her ilandan verileri çekme
    for listing in listings:
        # Başlık
        title_tag = listing.find('h3')
        title = title_tag.text.strip() if title_tag else 'N/A'
        
        # Oda sayısı - houseRoomCount class'ından
        room_tag = listing.find('span', class_='houseRoomCount')
        room = clean_room_text(room_tag.text) if room_tag else 'N/A'
        
        # Metrekare - squareMeter class'ından
        size_tag = listing.find('span', class_='squareMeter')
        size = size_tag.text.strip() if size_tag else 'N/A'
        
        # Bina yaşı - buildingAge class'ından
        age_tag = listing.find('span', class_='buildingAge')
        age = clean_age_text(age_tag.text) if age_tag else 'N/A'
        
        # Kat - floortype class'ından
        floor_tag = listing.find('span', class_='floortype')
        floor = floor_tag.text.strip() if floor_tag else 'N/A'
        
        # Konum - list-view-location class'ından
        location_tag = listing.find('span', class_='list-view-location')
        location = location_tag.text.strip() if location_tag else 'N/A'
        
        # For Sale/Rent status - left class içindeki span'dan
        status_tag = listing.find('span', class_='left')
        status = status_tag.text.strip() if status_tag else 'N/A'
        
        data.append({
            'status': status,
            'title': title,
            'location': location,
            'size': size,
            'room': room,
            'age': age,
            'floor': floor
        })

# WebDriver'ı kapatma
driver.quit()

# Verileri pandas DataFrame'e çevirme
df = pd.DataFrame(data)

# Verileri Excel dosyasına yazdırma
df.to_excel('hepsiemlak_listings.xlsx', index=False, engine='openpyxl')
print("Veriler başarıyla 'hepsiemlak_listings.xlsx' dosyasına kaydedildi.")
# Out:
# Veriler başarıyla 'hepsiemlak_listings.xlsx' dosyasına kaydedildi.

# %%
df
# Out:
#                 status                                              title  \
# 0   For Sale Apartment  115 Square Meters Apartment For Sale in Beylik...
# 1   For Sale Apartment  50 Square Meters Apartment For Sale in Esenyur...
# 2   For Sale Apartment  105 Square Meters Apartment For Sale in Küçükç...
# 3   For Sale Apartment  80 Square Meters Apartment For Sale in Esenyur...
# 4   For Sale Apartment  98 Square Meters Apartment For Sale in Bağcıla...
# 5   For Sale Apartment  100 Square Meters Apartment For Sale in Beylik...
# 6   For Sale Apartment  88 Square Meters Apartment For Sale in Esenyur...
# 7   For Sale Apartment  60 Square Meters Apartment For Sale in Küçükçe...
# 8   For Sale Apartment  95 Square Meters Apartment For Sale in Esenyur...
# 9   For Sale Apartment  500 Square Meters Apartment For Sale in Esenle...
# 10  For Sale Apartment  80 Square Meters Apartment For Sale in Küçükçe...
# 11  For Sale Apartment  115 Square Meters Apartment For Sale in Esenyu...
# 12  For Sale Apartment  110 Square Meters Apartment For Sale in Esenyu...
# 13  For Sale Apartment  70 Square Meters Apartment For Sale in Esenler...
# 14  For Sale Apartment  110 Square Meters Apartment For Sale in Esenyu...
# 15  For Sale Apartment  85 Square Meters Apartment For Sale in Esenyur...
# 16  For Sale Apartment  110 Square Meters Apartment For Sale in Esenyu...
# 17  For Sale Apartment  120 Square Meters Apartment For Sale in Esenyu...
# 18  For Sale Apartment  105 Square Meters Apartment For Sale in Esenyu...
# 19  For Sale Apartment  115 Square Meters Apartment For Sale in Beylik...
# 20  For Sale Apartment  50 Square Meters Apartment For Sale in Esenyur...
# 21  For Sale Apartment  105 Square Meters Apartment For Sale in Küçükç...
# 22  For Sale Apartment  80 Square Meters Apartment For Sale in Esenyur...
# 23  For Sale Apartment  98 Square Meters Apartment For Sale in Bağcıla...
# 24  For Sale Apartment  100 Square Meters Apartment For Sale in Beylik...
# 25  For Sale Apartment  88 Square Meters Apartment For Sale in Esenyur...
# 26  For Sale Apartment  60 Square Meters Apartment For Sale in Küçükçe...
# 27  For Sale Apartment  95 Square Meters Apartment For Sale in Esenyur...
# 28  For Sale Apartment  500 Square Meters Apartment For Sale in Esenle...
# 29  For Sale Apartment  80 Square Meters Apartment For Sale in Küçükçe...
# 30  For Sale Apartment  115 Square Meters Apartment For Sale in Esenyu...
# 31  For Sale Apartment  110 Square Meters Apartment For Sale in Esenyu...
# 32  For Sale Apartment  70 Square Meters Apartment For Sale in Esenler...
# 33  For Sale Apartment  110 Square Meters Apartment For Sale in Esenyu...
# 34  For Sale Apartment  85 Square Meters Apartment For Sale in Esenyur...
# 35  For Sale Apartment  110 Square Meters Apartment For Sale in Esenyu...
# 36  For Sale Apartment  120 Square Meters Apartment For Sale in Esenyu...
# 37  For Sale Apartment  105 Square Meters Apartment For Sale in Esenyu...
#
#                                       location    size    room           age  \
# 0      Istanbul / Beylikdüzü / Cumhuriyet Mah.  115 m²     2+1             4
# 1             Istanbul / Esenyurt / Pınar Mah.   50 m²  Stüdyo             8
# 2   Istanbul / Küçükçekmece / Mehmet Akif Mah.  105 m²     2+1            25
# 3          Istanbul / Esenyurt / Gökevler Mah.   80 m²     1+1             7
# 4        Istanbul / Bağcılar / Sancaktepe Mah.   98 m²     1+1            35
# 5      Istanbul / Beylikdüzü / Cumhuriyet Mah.  100 m²     2+1             5
# 6              Istanbul / Esenyurt / Koza Mah.   88 m²     1+1             1
# 7      Istanbul / Küçükçekmece / Yeşilova Mah.   60 m²     2+1            31
# 8              Istanbul / Esenyurt / Koza Mah.   95 m²     1+1  New Property
# 9              Istanbul / Esenler / Fatih Mah.  500 m²     1+1            12
# 10  Istanbul / Küçükçekmece / Mehmet Akif Mah.   80 m²     2+1            25
# 11        Istanbul / Esenyurt / Talatpaşa Mah.  115 m²     2+1             3
# 12        Istanbul / Esenyurt / Sultaniye Mah.  110 m²     2+1             2
# 13         Istanbul / Esenler / Davutpaşa Mah.   70 m²     1+1            27
# 14        Istanbul / Esenyurt / Güzelyurt Mah.  110 m²     2+1             5
# 15          Istanbul / Esenyurt / Mevlana Mah.   85 m²     1+1             5
# 16        Istanbul / Esenyurt / Güzelyurt Mah.  110 m²     2+1             4
# 17            Istanbul / Esenyurt / Fatih Mah.  120 m²     2+1             3
# 18            Istanbul / Esenyurt / Çınar Mah.  105 m²     2+1             5
# 19     Istanbul / Beylikdüzü / Cumhuriyet Mah.  115 m²     2+1             4
# 20            Istanbul / Esenyurt / Pınar Mah.   50 m²  Stüdyo             8
# 21  Istanbul / Küçükçekmece / Mehmet Akif Mah.  105 m²     2+1            25
# 22         Istanbul / Esenyurt / Gökevler Mah.   80 m²     1+1             7
# 23       Istanbul / Bağcılar / Sancaktepe Mah.   98 m²     1+1            35
# 24     Istanbul / Beylikdüzü / Cumhuriyet Mah.  100 m²     2+1             5
# 25             Istanbul / Esenyurt / Koza Mah.   88 m²     1+1             1
# 26     Istanbul / Küçükçekmece / Yeşilova Mah.   60 m²     2+1            31
# 27             Istanbul / Esenyurt / Koza Mah.   95 m²     1+1  New Property
# 28             Istanbul / Esenler / Fatih Mah.  500 m²     1+1            12
# 29  Istanbul / Küçükçekmece / Mehmet Akif Mah.   80 m²     2+1            25
# 30        Istanbul / Esenyurt / Talatpaşa Mah.  115 m²     2+1             3
# 31        Istanbul / Esenyurt / Sultaniye Mah.  110 m²     2+1             2
# 32         Istanbul / Esenler / Davutpaşa Mah.   70 m²     1+1            27
# 33        Istanbul / Esenyurt / Güzelyurt Mah.  110 m²     2+1             5
# 34          Istanbul / Esenyurt / Mevlana Mah.   85 m²     1+1             5
# 35        Istanbul / Esenyurt / Güzelyurt Mah.  110 m²     2+1             4
# 36            Istanbul / Esenyurt / Fatih Mah.  120 m²     2+1             3
# 37            Istanbul / Esenyurt / Çınar Mah.  105 m²     2+1             5
#
#            floor
# 0   Garden Floor
# 1       9. Floor
# 2   Garden Floor
# 3       4. Floor
# 4       Basement
# 5       2. Floor
# 6   21 and above
# 7   Garden Floor
# 8      14. Floor
# 9   Ground Floor
# 10      5. Floor
# 11  Garden Floor
# 12  Garden Floor
# 13  Garden Floor
# 14  Garden Floor
# 15      3. Floor
# 16  Garden Floor
# 17      2. Floor
# 18  Garden Floor
# 19  Garden Floor
# 20      9. Floor
# 21  Garden Floor
# 22      4. Floor
# 23      Basement
# 24      2. Floor
# 25  21 and above
# 26  Garden Floor
# 27     14. Floor
# 28  Ground Floor
# 29      5. Floor
# 30  Garden Floor
# 31  Garden Floor
# 32  Garden Floor
# 33  Garden Floor
# 34      3. Floor
# 35  Garden Floor
# 36      2. Floor
# 37  Garden Floor
